# %%
! python3 -m venv .venv && source .venv/bin/activate
! python -m pip install --upgrade pip
! pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu  # Mac M works with MPS even on "cpu" wheel
! pip install albumentations opencv-python tqdm numpy scikit-image matplotlib
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.12/site-packages (25.3)
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.12/site-packages (2.8.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.12/site-packages (0.23.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch) (69.5.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: albumentations in /opt/anaconda3/lib/python3.12/site-packages (2.0.8)
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: scikit-image in /opt/anaconda3/lib/python3.12/site-packages (0.23.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: scipy>=1.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.12/site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /opt/anaconda3/lib/python3.12/site-packages (from albumentations) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /opt/anaconda3/lib/python3.12/site-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /opt/anaconda3/lib/python3.12/site-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /opt/anaconda3/lib/python3.12/site-packages (from albucore==0.0.24->albumentations) (4.2.3)
# Requirement already satisfied: simsimd>=5.9.2 in /opt/anaconda3/lib/python3.12/site-packages (from albucore==0.0.24->albumentations) (6.5.3)
# Requirement already satisfied: networkx>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.1 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio>=2.33 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# 1) Activate your Python env
! python3 -m venv .venv && source .venv/bin/activate
! pip install opencv-python numpy

# 2) Run the prep script on your folder of plans
! python prep_split_and_weaklables.py \
  --in_dir "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/raw_data/images" \
  --out_root "./data" \
  --val_ratio 0.15 --test_ratio 0.10 --copy
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.2.6)
# Found 2640 images → train=1980 val=396 test=264
# [train] generating weak masks…
# [val] generating weak masks…
# Done. Empty/missing masks: 0
# Data root ready at: ./data
# Layout:
#   images/train, images/val, images/test
#   masks/train (weak), masks/val (weak)
#
# Next: point your training script to this root.

# %%
! python train_unet.py
# Out:
# /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Sena_PROJECT/FINAL/train_unet.py:41: UserWarning: Argument(s) 'mode, cval, cval_mask' are not valid for transform Affine
#   A.Affine(scale=(0.95, 1.05),
# Epoch 1/40: 100%|███████████████████████████| 1980/1980 [11:10<00:00,  2.95it/s]
# [E01] train_loss=0.1709  val_loss=0.1898  mIoU=0.8369
#    ↳ saved best to runs_unet/best.pt (mIoU=0.8369)
# Epoch 2/40: 100%|███████████████████████████| 1980/1980 [12:42<00:00,  2.60it/s]
# [E02] train_loss=0.1697  val_loss=0.2765  mIoU=0.6646
# Epoch 3/40: 100%|███████████████████████████| 1980/1980 [14:05<00:00,  2.34it/s]
# [E03] train_loss=0.1956  val_loss=1.1934  mIoU=0.3263
# Epoch 4/40: 100%|███████████████████████████| 1980/1980 [14:37<00:00,  2.26it/s]
# [E04] train_loss=0.2599  val_loss=0.4304  mIoU=0.6348
# Epoch 5/40: 100%|███████████████████████████| 1980/1980 [12:54<00:00,  2.56it/s]
# [E05] train_loss=0.3642  val_loss=0.4667  mIoU=0.6704
# Epoch 6/40: 100%|███████████████████████████| 1980/1980 [12:34<00:00,  2.62it/s]
# [E06] train_loss=0.3799  val_loss=0.3135  mIoU=0.6585
# Epoch 7/40: 100%|███████████████████████████| 1980/1980 [11:37<00:00,  2.84it/s]
# [E07] train_loss=0.3896  val_loss=0.3135  mIoU=0.6519
# Epoch 8/40: 100%|███████████████████████████| 1980/1980 [11:20<00:00,  2.91it/s]
# [E08] train_loss=0.4003  val_loss=1.0091  mIoU=0.3986
# Epoch 9/40: 100%|███████████████████████████| 1980/1980 [11:22<00:00,  2.90it/s]
# [E09] train_loss=0.3646  val_loss=0.7078  mIoU=0.3416
# Epoch 10/40: 100%|██████████████████████████| 1980/1980 [11:17<00:00,  2.92it/s]
# [E10] train_loss=0.3260  val_loss=0.9404  mIoU=0.3201
# Epoch 11/40: 100%|██████████████████████████| 1980/1980 [11:17<00:00,  2.92it/s]
# [E11] train_loss=0.3454  val_loss=1.4683  mIoU=0.0964
# Epoch 12/40: 100%|██████████████████████████| 1980/1980 [11:15<00:00,  2.93it/s]
# [E12] train_loss=0.3527  val_loss=1.5150  mIoU=0.0896
# Epoch 13/40: 100%|██████████████████████████| 1980/1980 [11:27<00:00,  2.88it/s]
# [E13] train_loss=0.3456  val_loss=2.2711  mIoU=0.0870
# Epoch 14/40: 100%|██████████████████████████| 1980/1980 [11:20<00:00,  2.91it/s]
# [E14] train_loss=0.3246  val_loss=1.0456  mIoU=0.2495
# Epoch 15/40: 100%|██████████████████████████| 1980/1980 [11:18<00:00,  2.92it/s]
# [E15] train_loss=0.3579  val_loss=0.7010  mIoU=0.4616
# Epoch 16/40: 100%|██████████████████████████| 1980/1980 [11:18<00:00,  2.92it/s]
# [E16] train_loss=0.3221  val_loss=0.3519  mIoU=0.6390
# Epoch 17/40: 100%|██████████████████████████| 1980/1980 [11:21<00:00,  2.91it/s]
# [E17] train_loss=0.3161  val_loss=0.5707  mIoU=0.6254
# Epoch 18/40: 100%|██████████████████████████| 1980/1980 [11:17<00:00,  2.92it/s]
# [E18] train_loss=0.3479  val_loss=2.5139  mIoU=0.1696
# Epoch 19/40: 100%|██████████████████████████| 1980/1980 [11:18<00:00,  2.92it/s]
# [E19] train_loss=0.4119  val_loss=2.7144  mIoU=0.0738
# Epoch 20/40: 100%|██████████████████████████| 1980/1980 [11:16<00:00,  2.93it/s]
# [E20] train_loss=0.3658  val_loss=0.3314  mIoU=0.5662
# Epoch 21/40: 100%|██████████████████████████| 1980/1980 [11:13<00:00,  2.94it/s]
# [E21] train_loss=0.7073  val_loss=0.9433  mIoU=0.0697
# Epoch 22/40: 100%|██████████████████████████| 1980/1980 [11:01<00:00,  2.99it/s]
# [E22] train_loss=0.7419  val_loss=1.0109  mIoU=0.0698
# Epoch 23/40: 100%|██████████████████████████| 1980/1980 [11:09<00:00,  2.96it/s]
# [E23] train_loss=0.7396  val_loss=1.1928  mIoU=0.0699
# Epoch 24/40: 100%|██████████████████████████| 1980/1980 [10:58<00:00,  3.00it/s]
# [E24] train_loss=0.7384  val_loss=1.0939  mIoU=0.0699
# Epoch 25/40: 100%|██████████████████████████| 1980/1980 [11:00<00:00,  3.00it/s]
# [E25] train_loss=0.7386  val_loss=1.2503  mIoU=0.0700
# Epoch 26/40: 100%|██████████████████████████| 1980/1980 [11:05<00:00,  2.98it/s]
# [E26] train_loss=0.7371  val_loss=1.1132  mIoU=0.0699
# Epoch 27/40: 100%|██████████████████████████| 1980/1980 [11:31<00:00,  2.86it/s]
# [E27] train_loss=0.7385  val_loss=1.3043  mIoU=0.0698
# Epoch 28/40: 100%|██████████████████████████| 1980/1980 [11:52<00:00,  2.78it/s]
# [E28] train_loss=0.7387  val_loss=1.5807  mIoU=0.0699
# Epoch 29/40: 100%|██████████████████████████| 1980/1980 [11:56<00:00,  2.76it/s]
# [E29] train_loss=0.7402  val_loss=0.9541  mIoU=0.0708
# Epoch 30/40: 100%|██████████████████████████| 1980/1980 [11:52<00:00,  2.78it/s]
# [E30] train_loss=0.7406  val_loss=1.0941  mIoU=0.0698
# Epoch 31/40: 100%|██████████████████████████| 1980/1980 [10:35<00:00,  3.11it/s]
# [E31] train_loss=0.7385  val_loss=1.0039  mIoU=0.0700
# Epoch 32/40: 100%|██████████████████████████| 1980/1980 [10:33<00:00,  3.13it/s]
# [E32] train_loss=0.7383  val_loss=1.3711  mIoU=0.0699
# Epoch 33/40: 100%|██████████████████████████| 1980/1980 [10:45<00:00,  3.07it/s]
# [E33] train_loss=0.7386  val_loss=1.0652  mIoU=0.0702
# Epoch 34/40: 100%|██████████████████████████| 1980/1980 [10:41<00:00,  3.09it/s]
# [E34] train_loss=0.7370  val_loss=1.1125  mIoU=0.0698
# Epoch 35/40: 100%|██████████████████████████| 1980/1980 [10:37<00:00,  3.11it/s]
# [E35] train_loss=0.7368  val_loss=1.3273  mIoU=0.0699
# Epoch 36/40: 100%|██████████████████████████| 1980/1980 [10:42<00:00,  3.08it/s]
# [E36] train_loss=0.7371  val_loss=1.0801  mIoU=0.0704
# Epoch 37/40: 100%|██████████████████████████| 1980/1980 [10:44<00:00,  3.07it/s]
# [E37] train_loss=0.7361  val_loss=1.1881  mIoU=0.0698
# Epoch 38/40: 100%|██████████████████████████| 1980/1980 [10:41<00:00,  3.09it/s]
# [E38] train_loss=0.7367  val_loss=1.2873  mIoU=0.0699
# Epoch 39/40: 100%|██████████████████████████| 1980/1980 [10:45<00:00,  3.07it/s]
# [E39] train_loss=0.7472  val_loss=1.2430  mIoU=0.0701
# Epoch 40/40: 100%|██████████████████████████| 1980/1980 [10:40<00:00,  3.09it/s]
# [E40] train_loss=0.7438  val_loss=1.6572  mIoU=0.0699

# %%
! python infer_unet.py
# Out:
# Traceback (most recent call last):
#   File "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/CIVIL-3D-PIPELINE/version one/infer_unet.py", line 218, in <module>
#     run_folder(
#   File "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/CIVIL-3D-PIPELINE/version one/infer_unet.py", line 186, in run_folder
#     raise FileNotFoundError(f"Folder not found: {folder_path}")
# FileNotFoundError: Folder not found: /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/CIVIL-3D-PIPELINE/version one/version one/data/images/test

# %%
! pip install shapely trimesh numpy
# Out:
# Requirement already satisfied: shapely in /opt/anaconda3/lib/python3.12/site-packages (2.1.0)
# Requirement already satisfied: trimesh in /opt/anaconda3/lib/python3.12/site-packages (4.6.10)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (1.26.4)

# %%
! python to3d.py
# Out:
# Found 264 polygons files in /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/pred_unet
#
# [1/264] 0_12_polygons.json → 0_12.glb
# 3D saved → out_3d/0_12.glb
# [2/264] 0_16_polygons.json → 0_16.glb
# 3D saved → out_3d/0_16.glb
# [3/264] 0_19_polygons.json → 0_19.glb
# 3D saved → out_3d/0_19.glb
# [4/264] 0_1_polygons.json → 0_1.glb
# 3D saved → out_3d/0_1.glb
# [5/264] 0_25_polygons.json → 0_25.glb
# 3D saved → out_3d/0_25.glb
# [6/264] 10_13_polygons.json → 10_13.glb
# 3D saved → out_3d/10_13.glb
# [7/264] 10_15_polygons.json → 10_15.glb
# 3D saved → out_3d/10_15.glb
# [8/264] 10_28_polygons.json → 10_28.glb
# 3D saved → out_3d/10_28.glb
# [9/264] 13_10_polygons.json → 13_10.glb
# 3D saved → out_3d/13_10.glb
# [10/264] 13_22_polygons.json → 13_22.glb
# 3D saved → out_3d/13_22.glb
# [11/264] 14_10_polygons.json → 14_10.glb
# 3D saved → out_3d/14_10.glb
# [12/264] 14_17_polygons.json → 14_17.glb
# 3D saved → out_3d/14_17.glb
# [13/264] 14_1_polygons.json → 14_1.glb
# 3D saved → out_3d/14_1.glb
# [14/264] 14_7_polygons.json → 14_7.glb
# 3D saved → out_3d/14_7.glb
# [15/264] 14_9_polygons.json → 14_9.glb
# 3D saved → out_3d/14_9.glb
# [16/264] 15_10_polygons.json → 15_10.glb
# 3D saved → out_3d/15_10.glb
# [17/264] 15_27_polygons.json → 15_27.glb
# 3D saved → out_3d/15_27.glb
# [18/264] 16_26_polygons.json → 16_26.glb
# 3D saved → out_3d/16_26.glb
# [19/264] 17_11_polygons.json → 17_11.glb
# 3D saved → out_3d/17_11.glb
# [20/264] 17_12_polygons.json → 17_12.glb
# 3D saved → out_3d/17_12.glb
# [21/264] 17_21_polygons.json → 17_21.glb
# 3D saved → out_3d/17_21.glb
# [22/264] 17_28_polygons.json → 17_28.glb
# 3D saved → out_3d/17_28.glb
# [23/264] 17_9_polygons.json → 17_9.glb
# 3D saved → out_3d/17_9.glb
# [24/264] 18_14_polygons.json → 18_14.glb
# 3D saved → out_3d/18_14.glb
# [25/264] 18_16_polygons.json → 18_16.glb
# 3D saved → out_3d/18_16.glb
# [26/264] 18_20_polygons.json → 18_20.glb
# 3D saved → out_3d/18_20.glb
# [27/264] 18_22_polygons.json → 18_22.glb
# 3D saved → out_3d/18_22.glb
# [28/264] 18_24_polygons.json → 18_24.glb
# 3D saved → out_3d/18_24.glb
# [29/264] 18_26_polygons.json → 18_26.glb
# 3D saved → out_3d/18_26.glb
# [30/264] 18_6_polygons.json → 18_6.glb
# 3D saved → out_3d/18_6.glb
# [31/264] 19_20_polygons.json → 19_20.glb
# 3D saved → out_3d/19_20.glb
# [32/264] 19_29_polygons.json → 19_29.glb
# 3D saved → out_3d/19_29.glb
# [33/264] 19_2_polygons.json → 19_2.glb
# 3D saved → out_3d/19_2.glb
# [34/264] 19_7_polygons.json → 19_7.glb
# 3D saved → out_3d/19_7.glb
# [35/264] 1_14_polygons.json → 1_14.glb
# 3D saved → out_3d/1_14.glb
# [36/264] 1_4_polygons.json → 1_4.glb
# 3D saved → out_3d/1_4.glb
# [37/264] 20_10_polygons.json → 20_10.glb
# 3D saved → out_3d/20_10.glb
# [38/264] 20_15_polygons.json → 20_15.glb
# 3D saved → out_3d/20_15.glb
# [39/264] 21_10_polygons.json → 21_10.glb
# 3D saved → out_3d/21_10.glb
# [40/264] 21_11_polygons.json → 21_11.glb
# 3D saved → out_3d/21_11.glb
# [41/264] 21_17_polygons.json → 21_17.glb
# 3D saved → out_3d/21_17.glb
# [42/264] 21_23_polygons.json → 21_23.glb
# 3D saved → out_3d/21_23.glb
# [43/264] 22_13_polygons.json → 22_13.glb
# 3D saved → out_3d/22_13.glb
# [44/264] 22_15_polygons.json → 22_15.glb
# 3D saved → out_3d/22_15.glb
# [45/264] 22_22_polygons.json → 22_22.glb
# 3D saved → out_3d/22_22.glb
# [46/264] 22_7_polygons.json → 22_7.glb
# 3D saved → out_3d/22_7.glb
# [47/264] 23_17_polygons.json → 23_17.glb
# 3D saved → out_3d/23_17.glb
# [48/264] 23_19_polygons.json → 23_19.glb
# 3D saved → out_3d/23_19.glb
# [49/264] 23_20_polygons.json → 23_20.glb
# 3D saved → out_3d/23_20.glb
# [50/264] 23_28_polygons.json → 23_28.glb
# 3D saved → out_3d/23_28.glb
# [51/264] 26_12_polygons.json → 26_12.glb
# 3D saved → out_3d/26_12.glb
# [52/264] 26_16_polygons.json → 26_16.glb
# 3D saved → out_3d/26_16.glb
# [53/264] 26_19_polygons.json → 26_19.glb
# 3D saved → out_3d/26_19.glb
# [54/264] 26_25_polygons.json → 26_25.glb
# 3D saved → out_3d/26_25.glb
# [55/264] 27_22_polygons.json → 27_22.glb
# 3D saved → out_3d/27_22.glb
# [56/264] 27_28_polygons.json → 27_28.glb
# 3D saved → out_3d/27_28.glb
# [57/264] 27_6_polygons.json → 27_6.glb
# 3D saved → out_3d/27_6.glb
# [58/264] 27_9_polygons.json → 27_9.glb
# 3D saved → out_3d/27_9.glb
# [59/264] 28_15_polygons.json → 28_15.glb
# 3D saved → out_3d/28_15.glb
# [60/264] 28_24_polygons.json → 28_24.glb
# 3D saved → out_3d/28_24.glb
# [61/264] 28_29_polygons.json → 28_29.glb
# 3D saved → out_3d/28_29.glb
# [62/264] 28_30_polygons.json → 28_30.glb
# 3D saved → out_3d/28_30.glb
# [63/264] 28_4_polygons.json → 28_4.glb
# 3D saved → out_3d/28_4.glb
# [64/264] 28_7_polygons.json → 28_7.glb
# 3D saved → out_3d/28_7.glb
# [65/264] 2_4_polygons.json → 2_4.glb
# 3D saved → out_3d/2_4.glb
# [66/264] 2_7_polygons.json → 2_7.glb
# 3D saved → out_3d/2_7.glb
# [67/264] 30_14_polygons.json → 30_14.glb
# 3D saved → out_3d/30_14.glb
# [68/264] 30_28_polygons.json → 30_28.glb
# 3D saved → out_3d/30_28.glb
# [69/264] 30_4_polygons.json → 30_4.glb
# 3D saved → out_3d/30_4.glb
# [70/264] 30_8_polygons.json → 30_8.glb
# 3D saved → out_3d/30_8.glb
# [71/264] 31_21_polygons.json → 31_21.glb
# 3D saved → out_3d/31_21.glb
# [72/264] 31_9_polygons.json → 31_9.glb
# 3D saved → out_3d/31_9.glb
# [73/264] 32_16_polygons.json → 32_16.glb
# 3D saved → out_3d/32_16.glb
# [74/264] 32_22_polygons.json → 32_22.glb
# 3D saved → out_3d/32_22.glb
# [75/264] 32_23_polygons.json → 32_23.glb
# 3D saved → out_3d/32_23.glb
# [76/264] 32_28_polygons.json → 32_28.glb
# 3D saved → out_3d/32_28.glb
# [77/264] 33_27_polygons.json → 33_27.glb
# 3D saved → out_3d/33_27.glb
# [78/264] 34_17_polygons.json → 34_17.glb
# 3D saved → out_3d/34_17.glb
# [79/264] 34_19_polygons.json → 34_19.glb
# 3D saved → out_3d/34_19.glb
# [80/264] 34_21_polygons.json → 34_21.glb
# 3D saved → out_3d/34_21.glb
# [81/264] 35_21_polygons.json → 35_21.glb
# 3D saved → out_3d/35_21.glb
# [82/264] 35_28_polygons.json → 35_28.glb
# 3D saved → out_3d/35_28.glb
# [83/264] 36_16_polygons.json → 36_16.glb
# 3D saved → out_3d/36_16.glb
# [84/264] 36_25_polygons.json → 36_25.glb
# 3D saved → out_3d/36_25.glb
# [85/264] 36_5_polygons.json → 36_5.glb
# 3D saved → out_3d/36_5.glb
# [86/264] 36_8_polygons.json → 36_8.glb
# 3D saved → out_3d/36_8.glb
# [87/264] 39_12_polygons.json → 39_12.glb
# 3D saved → out_3d/39_12.glb
# [88/264] 39_27_polygons.json → 39_27.glb
# 3D saved → out_3d/39_27.glb
# [89/264] 39_5_polygons.json → 39_5.glb
# 3D saved → out_3d/39_5.glb
# [90/264] 3_11_polygons.json → 3_11.glb
# 3D saved → out_3d/3_11.glb
# [91/264] 3_20_polygons.json → 3_20.glb
# 3D saved → out_3d/3_20.glb
# [92/264] 3_22_polygons.json → 3_22.glb
# 3D saved → out_3d/3_22.glb
# [93/264] 3_4_polygons.json → 3_4.glb
# 3D saved → out_3d/3_4.glb
# [94/264] 40_8_polygons.json → 40_8.glb
# 3D saved → out_3d/40_8.glb
# [95/264] 41_13_polygons.json → 41_13.glb
# 3D saved → out_3d/41_13.glb
# [96/264] 41_14_polygons.json → 41_14.glb
# 3D saved → out_3d/41_14.glb
# [97/264] 41_29_polygons.json → 41_29.glb
# 3D saved → out_3d/41_29.glb
# [98/264] 41_30_polygons.json → 41_30.glb
# 3D saved → out_3d/41_30.glb
# [99/264] 41_5_polygons.json → 41_5.glb
# 3D saved → out_3d/41_5.glb
# [100/264] 41_9_polygons.json → 41_9.glb
# 3D saved → out_3d/41_9.glb
# [101/264] 42_21_polygons.json → 42_21.glb
# 3D saved → out_3d/42_21.glb
# [102/264] 43_1_polygons.json → 43_1.glb
# 3D saved → out_3d/43_1.glb
# [103/264] 44_13_polygons.json → 44_13.glb
# 3D saved → out_3d/44_13.glb
# [104/264] 44_26_polygons.json → 44_26.glb
# 3D saved → out_3d/44_26.glb
# [105/264] 44_4_polygons.json → 44_4.glb
# 3D saved → out_3d/44_4.glb
# [106/264] 44_7_polygons.json → 44_7.glb
# 3D saved → out_3d/44_7.glb
# [107/264] 45_20_polygons.json → 45_20.glb
# 3D saved → out_3d/45_20.glb
# [108/264] 45_30_polygons.json → 45_30.glb
# 3D saved → out_3d/45_30.glb
# [109/264] 47_12_polygons.json → 47_12.glb
# 3D saved → out_3d/47_12.glb
# [110/264] 47_24_polygons.json → 47_24.glb
# 3D saved → out_3d/47_24.glb
# [111/264] 47_30_polygons.json → 47_30.glb
# 3D saved → out_3d/47_30.glb
# [112/264] 48_10_polygons.json → 48_10.glb
# 3D saved → out_3d/48_10.glb
# [113/264] 48_19_polygons.json → 48_19.glb
# 3D saved → out_3d/48_19.glb
# [114/264] 48_29_polygons.json → 48_29.glb
# 3D saved → out_3d/48_29.glb
# [115/264] 48_7_polygons.json → 48_7.glb
# 3D saved → out_3d/48_7.glb
# [116/264] 48_8_polygons.json → 48_8.glb
# 3D saved → out_3d/48_8.glb
# [117/264] 4_19_polygons.json → 4_19.glb
# 3D saved → out_3d/4_19.glb
# [118/264] 4_22_polygons.json → 4_22.glb
# 3D saved → out_3d/4_22.glb
# [119/264] 4_5_polygons.json → 4_5.glb
# 3D saved → out_3d/4_5.glb
# [120/264] 51_18_polygons.json → 51_18.glb
# 3D saved → out_3d/51_18.glb
# [121/264] 51_29_polygons.json → 51_29.glb
# 3D saved → out_3d/51_29.glb
# [122/264] 52_12_polygons.json → 52_12.glb
# 3D saved → out_3d/52_12.glb
# [123/264] 52_17_polygons.json → 52_17.glb
# 3D saved → out_3d/52_17.glb
# [124/264] 52_20_polygons.json → 52_20.glb
# 3D saved → out_3d/52_20.glb
# [125/264] 52_2_polygons.json → 52_2.glb
# 3D saved → out_3d/52_2.glb
# [126/264] 53_14_polygons.json → 53_14.glb
# 3D saved → out_3d/53_14.glb
# [127/264] 53_16_polygons.json → 53_16.glb
# 3D saved → out_3d/53_16.glb
# [128/264] 53_17_polygons.json → 53_17.glb
# 3D saved → out_3d/53_17.glb
# [129/264] 53_6_polygons.json → 53_6.glb
# 3D saved → out_3d/53_6.glb
# [130/264] 54_21_polygons.json → 54_21.glb
# 3D saved → out_3d/54_21.glb
# [131/264] 55_10_polygons.json → 55_10.glb
# 3D saved → out_3d/55_10.glb
# [132/264] 56_13_polygons.json → 56_13.glb
# 3D saved → out_3d/56_13.glb
# [133/264] 57_26_polygons.json → 57_26.glb
# 3D saved → out_3d/57_26.glb
# [134/264] 58_29_polygons.json → 58_29.glb
# 3D saved → out_3d/58_29.glb
# [135/264] 58_30_polygons.json → 58_30.glb
# 3D saved → out_3d/58_30.glb
# [136/264] 58_7_polygons.json → 58_7.glb
# 3D saved → out_3d/58_7.glb
# [137/264] 59_10_polygons.json → 59_10.glb
# 3D saved → out_3d/59_10.glb
# [138/264] 59_14_polygons.json → 59_14.glb
# 3D saved → out_3d/59_14.glb
# [139/264] 59_18_polygons.json → 59_18.glb
# 3D saved → out_3d/59_18.glb
# [140/264] 59_1_polygons.json → 59_1.glb
# 3D saved → out_3d/59_1.glb
# [141/264] 5_16_polygons.json → 5_16.glb
# 3D saved → out_3d/5_16.glb
# [142/264] 5_22_polygons.json → 5_22.glb
# 3D saved → out_3d/5_22.glb
# [143/264] 5_25_polygons.json → 5_25.glb
# 3D saved → out_3d/5_25.glb
# [144/264] 60_19_polygons.json → 60_19.glb
# 3D saved → out_3d/60_19.glb
# [145/264] 60_20_polygons.json → 60_20.glb
# 3D saved → out_3d/60_20.glb
# [146/264] 60_26_polygons.json → 60_26.glb
# 3D saved → out_3d/60_26.glb
# [147/264] 60_6_polygons.json → 60_6.glb
# 3D saved → out_3d/60_6.glb
# [148/264] 60_9_polygons.json → 60_9.glb
# 3D saved → out_3d/60_9.glb
# [149/264] 61_21_polygons.json → 61_21.glb
# 3D saved → out_3d/61_21.glb
# [150/264] 61_24_polygons.json → 61_24.glb
# 3D saved → out_3d/61_24.glb
# [151/264] 62_26_polygons.json → 62_26.glb
# 3D saved → out_3d/62_26.glb
# [152/264] 62_27_polygons.json → 62_27.glb
# 3D saved → out_3d/62_27.glb
# [153/264] 62_29_polygons.json → 62_29.glb
# 3D saved → out_3d/62_29.glb
# [154/264] 63_12_polygons.json → 63_12.glb
# 3D saved → out_3d/63_12.glb
# [155/264] 63_3_polygons.json → 63_3.glb
# 3D saved → out_3d/63_3.glb
# [156/264] 65_20_polygons.json → 65_20.glb
# 3D saved → out_3d/65_20.glb
# [157/264] 65_30_polygons.json → 65_30.glb
# 3D saved → out_3d/65_30.glb
# [158/264] 65_9_polygons.json → 65_9.glb
# 3D saved → out_3d/65_9.glb
# [159/264] 66_16_polygons.json → 66_16.glb
# 3D saved → out_3d/66_16.glb
# [160/264] 66_27_polygons.json → 66_27.glb
# 3D saved → out_3d/66_27.glb
# [161/264] 67_13_polygons.json → 67_13.glb
# 3D saved → out_3d/67_13.glb
# [162/264] 67_27_polygons.json → 67_27.glb
# 3D saved → out_3d/67_27.glb
# [163/264] 67_3_polygons.json → 67_3.glb
# 3D saved → out_3d/67_3.glb
# [164/264] 67_4_polygons.json → 67_4.glb
# 3D saved → out_3d/67_4.glb
# [165/264] 67_8_polygons.json → 67_8.glb
# 3D saved → out_3d/67_8.glb
# [166/264] 68_14_polygons.json → 68_14.glb
# 3D saved → out_3d/68_14.glb
# [167/264] 68_29_polygons.json → 68_29.glb
# 3D saved → out_3d/68_29.glb
# [168/264] 69_11_polygons.json → 69_11.glb
# 3D saved → out_3d/69_11.glb
# [169/264] 6_16_polygons.json → 6_16.glb
# 3D saved → out_3d/6_16.glb
# [170/264] 6_1_polygons.json → 6_1.glb
# 3D saved → out_3d/6_1.glb
# [171/264] 6_21_polygons.json → 6_21.glb
# 3D saved → out_3d/6_21.glb
# [172/264] 6_4_polygons.json → 6_4.glb
# 3D saved → out_3d/6_4.glb
# [173/264] 70_1_polygons.json → 70_1.glb
# 3D saved → out_3d/70_1.glb
# [174/264] 70_21_polygons.json → 70_21.glb
# 3D saved → out_3d/70_21.glb
# [175/264] 70_23_polygons.json → 70_23.glb
# 3D saved → out_3d/70_23.glb
# [176/264] 70_25_polygons.json → 70_25.glb
# 3D saved → out_3d/70_25.glb
# [177/264] 71_12_polygons.json → 71_12.glb
# 3D saved → out_3d/71_12.glb
# [178/264] 71_1_polygons.json → 71_1.glb
# 3D saved → out_3d/71_1.glb
# [179/264] 71_9_polygons.json → 71_9.glb
# 3D saved → out_3d/71_9.glb
# [180/264] 72_10_polygons.json → 72_10.glb
# 3D saved → out_3d/72_10.glb
# [181/264] 72_21_polygons.json → 72_21.glb
# 3D saved → out_3d/72_21.glb
# [182/264] 72_28_polygons.json → 72_28.glb
# 3D saved → out_3d/72_28.glb
# [183/264] 72_3_polygons.json → 72_3.glb
# 3D saved → out_3d/72_3.glb
# [184/264] 73_13_polygons.json → 73_13.glb
# 3D saved → out_3d/73_13.glb
# [185/264] 73_24_polygons.json → 73_24.glb
# 3D saved → out_3d/73_24.glb
# [186/264] 73_30_polygons.json → 73_30.glb
# 3D saved → out_3d/73_30.glb
# [187/264] 74_12_polygons.json → 74_12.glb
# 3D saved → out_3d/74_12.glb
# [188/264] 75_28_polygons.json → 75_28.glb
# 3D saved → out_3d/75_28.glb
# [189/264] 75_7_polygons.json → 75_7.glb
# 3D saved → out_3d/75_7.glb
# [190/264] 75_8_polygons.json → 75_8.glb
# 3D saved → out_3d/75_8.glb
# [191/264] 76_1_polygons.json → 76_1.glb
# 3D saved → out_3d/76_1.glb
# [192/264] 76_29_polygons.json → 76_29.glb
# 3D saved → out_3d/76_29.glb
# [193/264] 76_8_polygons.json → 76_8.glb
# 3D saved → out_3d/76_8.glb
# [194/264] 77_23_polygons.json → 77_23.glb
# 3D saved → out_3d/77_23.glb
# [195/264] 77_27_polygons.json → 77_27.glb
# 3D saved → out_3d/77_27.glb
# [196/264] 78_25_polygons.json → 78_25.glb
# 3D saved → out_3d/78_25.glb
# [197/264] 78_27_polygons.json → 78_27.glb
# 3D saved → out_3d/78_27.glb
# [198/264] 78_4_polygons.json → 78_4.glb
# 3D saved → out_3d/78_4.glb
# [199/264] 79_16_polygons.json → 79_16.glb
# 3D saved → out_3d/79_16.glb
# [200/264] 79_1_polygons.json → 79_1.glb
# 3D saved → out_3d/79_1.glb
# [201/264] 79_25_polygons.json → 79_25.glb
# 3D saved → out_3d/79_25.glb
# [202/264] 79_2_polygons.json → 79_2.glb
# 3D saved → out_3d/79_2.glb
# [203/264] 79_8_polygons.json → 79_8.glb
# 3D saved → out_3d/79_8.glb
# [204/264] 7_28_polygons.json → 7_28.glb
# 3D saved → out_3d/7_28.glb
# [205/264] 7_29_polygons.json → 7_29.glb
# 3D saved → out_3d/7_29.glb
# [206/264] 80_22_polygons.json → 80_22.glb
# 3D saved → out_3d/80_22.glb
# [207/264] 80_3_polygons.json → 80_3.glb
# 3D saved → out_3d/80_3.glb
# [208/264] 81_12_polygons.json → 81_12.glb
# 3D saved → out_3d/81_12.glb
# [209/264] 81_15_polygons.json → 81_15.glb
# 3D saved → out_3d/81_15.glb
# [210/264] 82_10_polygons.json → 82_10.glb
# 3D saved → out_3d/82_10.glb
# [211/264] 82_8_polygons.json → 82_8.glb
# 3D saved → out_3d/82_8.glb
# [212/264] 84_11_polygons.json → 84_11.glb
# 3D saved → out_3d/84_11.glb
# [213/264] 84_18_polygons.json → 84_18.glb
# 3D saved → out_3d/84_18.glb
# [214/264] 84_6_polygons.json → 84_6.glb
# 3D saved → out_3d/84_6.glb
# [215/264] 85_19_polygons.json → 85_19.glb
# 3D saved → out_3d/85_19.glb
# [216/264] 85_21_polygons.json → 85_21.glb
# 3D saved → out_3d/85_21.glb
# [217/264] 86_11_polygons.json → 86_11.glb
# 3D saved → out_3d/86_11.glb
# [218/264] 86_24_polygons.json → 86_24.glb
# 3D saved → out_3d/86_24.glb
# [219/264] 86_25_polygons.json → 86_25.glb
# 3D saved → out_3d/86_25.glb
# [220/264] 86_2_polygons.json → 86_2.glb
# 3D saved → out_3d/86_2.glb
# [221/264] 86_3_polygons.json → 86_3.glb
# 3D saved → out_3d/86_3.glb
# [222/264] 87_15_polygons.json → 87_15.glb
# 3D saved → out_3d/87_15.glb
# [223/264] 87_25_polygons.json → 87_25.glb
# 3D saved → out_3d/87_25.glb
# [224/264] 87_9_polygons.json → 87_9.glb
# 3D saved → out_3d/87_9.glb
# [225/264] 88_15_polygons.json → 88_15.glb
# 3D saved → out_3d/88_15.glb
# [226/264] 88_21_polygons.json → 88_21.glb
# 3D saved → out_3d/88_21.glb
# [227/264] 88_23_polygons.json → 88_23.glb
# 3D saved → out_3d/88_23.glb
# [228/264] 88_9_polygons.json → 88_9.glb
# 3D saved → out_3d/88_9.glb
# [229/264] 89_18_polygons.json → 89_18.glb
# 3D saved → out_3d/89_18.glb
# [230/264] 89_2_polygons.json → 89_2.glb
# 3D saved → out_3d/89_2.glb
# [231/264] 89_4_polygons.json → 89_4.glb
# 3D saved → out_3d/89_4.glb
# [232/264] 89_9_polygons.json → 89_9.glb
# 3D saved → out_3d/89_9.glb
# [233/264] 8_10_polygons.json → 8_10.glb
# 3D saved → out_3d/8_10.glb
# [234/264] 8_18_polygons.json → 8_18.glb
# 3D saved → out_3d/8_18.glb
# [235/264] 8_2_polygons.json → 8_2.glb
# 3D saved → out_3d/8_2.glb
# [236/264] 8_3_polygons.json → 8_3.glb
# 3D saved → out_3d/8_3.glb
# [237/264] 8_8_polygons.json → 8_8.glb
# 3D saved → out_3d/8_8.glb
# [238/264] 90_11_polygons.json → 90_11.glb
# 3D saved → out_3d/90_11.glb
# [239/264] 90_12_polygons.json → 90_12.glb
# 3D saved → out_3d/90_12.glb
# [240/264] 90_23_polygons.json → 90_23.glb
# 3D saved → out_3d/90_23.glb
# [241/264] 90_3_polygons.json → 90_3.glb
# 3D saved → out_3d/90_3.glb
# [242/264] 90_6_polygons.json → 90_6.glb
# 3D saved → out_3d/90_6.glb
# [243/264] 90_8_polygons.json → 90_8.glb
# 3D saved → out_3d/90_8.glb
# [244/264] 91_28_polygons.json → 91_28.glb
# 3D saved → out_3d/91_28.glb
# [245/264] 92_15_polygons.json → 92_15.glb
# 3D saved → out_3d/92_15.glb
# [246/264] 92_29_polygons.json → 92_29.glb
# 3D saved → out_3d/92_29.glb
# [247/264] 93_17_polygons.json → 93_17.glb
# 3D saved → out_3d/93_17.glb
# [248/264] 93_2_polygons.json → 93_2.glb
# 3D saved → out_3d/93_2.glb
# [249/264] 94_17_polygons.json → 94_17.glb
# 3D saved → out_3d/94_17.glb
# [250/264] 94_1_polygons.json → 94_1.glb
# 3D saved → out_3d/94_1.glb
# [251/264] 94_20_polygons.json → 94_20.glb
# 3D saved → out_3d/94_20.glb
# [252/264] 94_4_polygons.json → 94_4.glb
# 3D saved → out_3d/94_4.glb
# [253/264] 95_18_polygons.json → 95_18.glb
# 3D saved → out_3d/95_18.glb
# [254/264] 95_1_polygons.json → 95_1.glb
# 3D saved → out_3d/95_1.glb
# [255/264] 95_24_polygons.json → 95_24.glb
# 3D saved → out_3d/95_24.glb
# [256/264] 95_8_polygons.json → 95_8.glb
# 3D saved → out_3d/95_8.glb
# [257/264] 96_21_polygons.json → 96_21.glb
# 3D saved → out_3d/96_21.glb
# [258/264] 96_28_polygons.json → 96_28.glb
# 3D saved → out_3d/96_28.glb
# [259/264] 98_18_polygons.json → 98_18.glb
# 3D saved → out_3d/98_18.glb
# [260/264] 9_19_polygons.json → 9_19.glb
# 3D saved → out_3d/9_19.glb
# [261/264] 9_1_polygons.json → 9_1.glb
# 3D saved → out_3d/9_1.glb
# [262/264] 9_22_polygons.json → 9_22.glb
# 3D saved → out_3d/9_22.glb
# [263/264] 9_29_polygons.json → 9_29.glb
# 3D saved → out_3d/9_29.glb
# [264/264] 9_7_polygons.json → 9_7.glb
# 3D saved → out_3d/9_7.glb
#
# DONE: exported all available models to out_3d

# %%
from IPython.display import HTML

HTML('''
<script type="module" src="https://unpkg.com/@google/model-viewer@3.4.0/dist/model-viewer.min.js"></script>
''')
# Out:
# <script type="module" src="https://unpkg.com/@google/model-viewer@3.4.0/dist/model-viewer.min.js"></script>

# %%
from IPython.display import HTML

glb_path = "version one/out_3d/3_4.glb"

HTML(f"""
<model-viewer src="{glb_path}"
    camera-controls
    auto-rotate
    environment-image="neutral"
    style="width:100%; height:600px; background:black;">
</model-viewer>
""")
# Out:
# <model-viewer src="version one/out_3d/3_4.glb"
#     camera-controls
#     auto-rotate
#     environment-image="neutral"
#     style="width:100%; height:600px; background:black;">
# </model-viewer>

# %%
! python to3d_colour.py
# Out:
# Found 264 polygons files in /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/pred_unet
#
# [1/264] 0_12_polygons.json → 0_12.glb
# 3D saved → out_3d_colour/0_12.glb
# [2/264] 0_16_polygons.json → 0_16.glb
# 3D saved → out_3d_colour/0_16.glb
# [3/264] 0_19_polygons.json → 0_19.glb
# 3D saved → out_3d_colour/0_19.glb
# [4/264] 0_1_polygons.json → 0_1.glb
# 3D saved → out_3d_colour/0_1.glb
# [5/264] 0_25_polygons.json → 0_25.glb
# 3D saved → out_3d_colour/0_25.glb
# [6/264] 10_13_polygons.json → 10_13.glb
# 3D saved → out_3d_colour/10_13.glb
# [7/264] 10_15_polygons.json → 10_15.glb
# 3D saved → out_3d_colour/10_15.glb
# [8/264] 10_28_polygons.json → 10_28.glb
# 3D saved → out_3d_colour/10_28.glb
# [9/264] 13_10_polygons.json → 13_10.glb
# 3D saved → out_3d_colour/13_10.glb
# [10/264] 13_22_polygons.json → 13_22.glb
# 3D saved → out_3d_colour/13_22.glb
# [11/264] 14_10_polygons.json → 14_10.glb
# 3D saved → out_3d_colour/14_10.glb
# [12/264] 14_17_polygons.json → 14_17.glb
# 3D saved → out_3d_colour/14_17.glb
# [13/264] 14_1_polygons.json → 14_1.glb
# 3D saved → out_3d_colour/14_1.glb
# [14/264] 14_7_polygons.json → 14_7.glb
# 3D saved → out_3d_colour/14_7.glb
# [15/264] 14_9_polygons.json → 14_9.glb
# 3D saved → out_3d_colour/14_9.glb
# [16/264] 15_10_polygons.json → 15_10.glb
# 3D saved → out_3d_colour/15_10.glb
# [17/264] 15_27_polygons.json → 15_27.glb
# 3D saved → out_3d_colour/15_27.glb
# [18/264] 16_26_polygons.json → 16_26.glb
# 3D saved → out_3d_colour/16_26.glb
# [19/264] 17_11_polygons.json → 17_11.glb
# 3D saved → out_3d_colour/17_11.glb
# [20/264] 17_12_polygons.json → 17_12.glb
# 3D saved → out_3d_colour/17_12.glb
# [21/264] 17_21_polygons.json → 17_21.glb
# 3D saved → out_3d_colour/17_21.glb
# [22/264] 17_28_polygons.json → 17_28.glb
# 3D saved → out_3d_colour/17_28.glb
# [23/264] 17_9_polygons.json → 17_9.glb
# 3D saved → out_3d_colour/17_9.glb
# [24/264] 18_14_polygons.json → 18_14.glb
# 3D saved → out_3d_colour/18_14.glb
# [25/264] 18_16_polygons.json → 18_16.glb
# 3D saved → out_3d_colour/18_16.glb
# [26/264] 18_20_polygons.json → 18_20.glb
# 3D saved → out_3d_colour/18_20.glb
# [27/264] 18_22_polygons.json → 18_22.glb
# 3D saved → out_3d_colour/18_22.glb
# [28/264] 18_24_polygons.json → 18_24.glb
# 3D saved → out_3d_colour/18_24.glb
# [29/264] 18_26_polygons.json → 18_26.glb
# 3D saved → out_3d_colour/18_26.glb
# [30/264] 18_6_polygons.json → 18_6.glb
# 3D saved → out_3d_colour/18_6.glb
# [31/264] 19_20_polygons.json → 19_20.glb
# 3D saved → out_3d_colour/19_20.glb
# [32/264] 19_29_polygons.json → 19_29.glb
# 3D saved → out_3d_colour/19_29.glb
# [33/264] 19_2_polygons.json → 19_2.glb
# 3D saved → out_3d_colour/19_2.glb
# [34/264] 19_7_polygons.json → 19_7.glb
# 3D saved → out_3d_colour/19_7.glb
# [35/264] 1_14_polygons.json → 1_14.glb
# 3D saved → out_3d_colour/1_14.glb
# [36/264] 1_4_polygons.json → 1_4.glb
# 3D saved → out_3d_colour/1_4.glb
# [37/264] 20_10_polygons.json → 20_10.glb
# 3D saved → out_3d_colour/20_10.glb
# [38/264] 20_15_polygons.json → 20_15.glb
# 3D saved → out_3d_colour/20_15.glb
# [39/264] 21_10_polygons.json → 21_10.glb
# 3D saved → out_3d_colour/21_10.glb
# [40/264] 21_11_polygons.json → 21_11.glb
# 3D saved → out_3d_colour/21_11.glb
# [41/264] 21_17_polygons.json → 21_17.glb
# 3D saved → out_3d_colour/21_17.glb
# [42/264] 21_23_polygons.json → 21_23.glb
# 3D saved → out_3d_colour/21_23.glb
# [43/264] 22_13_polygons.json → 22_13.glb
# 3D saved → out_3d_colour/22_13.glb
# [44/264] 22_15_polygons.json → 22_15.glb
# 3D saved → out_3d_colour/22_15.glb
# [45/264] 22_22_polygons.json → 22_22.glb
# 3D saved → out_3d_colour/22_22.glb
# [46/264] 22_7_polygons.json → 22_7.glb
# 3D saved → out_3d_colour/22_7.glb
# [47/264] 23_17_polygons.json → 23_17.glb
# 3D saved → out_3d_colour/23_17.glb
# [48/264] 23_19_polygons.json → 23_19.glb
# 3D saved → out_3d_colour/23_19.glb
# [49/264] 23_20_polygons.json → 23_20.glb
# 3D saved → out_3d_colour/23_20.glb
# [50/264] 23_28_polygons.json → 23_28.glb
# 3D saved → out_3d_colour/23_28.glb
# [51/264] 26_12_polygons.json → 26_12.glb
# 3D saved → out_3d_colour/26_12.glb
# [52/264] 26_16_polygons.json → 26_16.glb
# 3D saved → out_3d_colour/26_16.glb
# [53/264] 26_19_polygons.json → 26_19.glb
# 3D saved → out_3d_colour/26_19.glb
# [54/264] 26_25_polygons.json → 26_25.glb
# 3D saved → out_3d_colour/26_25.glb
# [55/264] 27_22_polygons.json → 27_22.glb
# 3D saved → out_3d_colour/27_22.glb
# [56/264] 27_28_polygons.json → 27_28.glb
# 3D saved → out_3d_colour/27_28.glb
# [57/264] 27_6_polygons.json → 27_6.glb
# 3D saved → out_3d_colour/27_6.glb
# [58/264] 27_9_polygons.json → 27_9.glb
# 3D saved → out_3d_colour/27_9.glb
# [59/264] 28_15_polygons.json → 28_15.glb
# 3D saved → out_3d_colour/28_15.glb
# [60/264] 28_24_polygons.json → 28_24.glb
# 3D saved → out_3d_colour/28_24.glb
# [61/264] 28_29_polygons.json → 28_29.glb
# 3D saved → out_3d_colour/28_29.glb
# [62/264] 28_30_polygons.json → 28_30.glb
# 3D saved → out_3d_colour/28_30.glb
# [63/264] 28_4_polygons.json → 28_4.glb
# 3D saved → out_3d_colour/28_4.glb
# [64/264] 28_7_polygons.json → 28_7.glb
# 3D saved → out_3d_colour/28_7.glb
# [65/264] 2_4_polygons.json → 2_4.glb
# 3D saved → out_3d_colour/2_4.glb
# [66/264] 2_7_polygons.json → 2_7.glb
# 3D saved → out_3d_colour/2_7.glb
# [67/264] 30_14_polygons.json → 30_14.glb
# 3D saved → out_3d_colour/30_14.glb
# [68/264] 30_28_polygons.json → 30_28.glb
# 3D saved → out_3d_colour/30_28.glb
# [69/264] 30_4_polygons.json → 30_4.glb
# 3D saved → out_3d_colour/30_4.glb
# [70/264] 30_8_polygons.json → 30_8.glb
# 3D saved → out_3d_colour/30_8.glb
# [71/264] 31_21_polygons.json → 31_21.glb
# 3D saved → out_3d_colour/31_21.glb
# [72/264] 31_9_polygons.json → 31_9.glb
# 3D saved → out_3d_colour/31_9.glb
# [73/264] 32_16_polygons.json → 32_16.glb
# 3D saved → out_3d_colour/32_16.glb
# [74/264] 32_22_polygons.json → 32_22.glb
# 3D saved → out_3d_colour/32_22.glb
# [75/264] 32_23_polygons.json → 32_23.glb
# 3D saved → out_3d_colour/32_23.glb
# [76/264] 32_28_polygons.json → 32_28.glb
# 3D saved → out_3d_colour/32_28.glb
# [77/264] 33_27_polygons.json → 33_27.glb
# 3D saved → out_3d_colour/33_27.glb
# [78/264] 34_17_polygons.json → 34_17.glb
# 3D saved → out_3d_colour/34_17.glb
# [79/264] 34_19_polygons.json → 34_19.glb
# 3D saved → out_3d_colour/34_19.glb
# [80/264] 34_21_polygons.json → 34_21.glb
# 3D saved → out_3d_colour/34_21.glb
# [81/264] 35_21_polygons.json → 35_21.glb
# 3D saved → out_3d_colour/35_21.glb
# [82/264] 35_28_polygons.json → 35_28.glb
# 3D saved → out_3d_colour/35_28.glb
# [83/264] 36_16_polygons.json → 36_16.glb
# 3D saved → out_3d_colour/36_16.glb
# [84/264] 36_25_polygons.json → 36_25.glb
# 3D saved → out_3d_colour/36_25.glb
# [85/264] 36_5_polygons.json → 36_5.glb
# 3D saved → out_3d_colour/36_5.glb
# [86/264] 36_8_polygons.json → 36_8.glb
# 3D saved → out_3d_colour/36_8.glb
# [87/264] 39_12_polygons.json → 39_12.glb
# 3D saved → out_3d_colour/39_12.glb
# [88/264] 39_27_polygons.json → 39_27.glb
# 3D saved → out_3d_colour/39_27.glb
# [89/264] 39_5_polygons.json → 39_5.glb
# 3D saved → out_3d_colour/39_5.glb
# [90/264] 3_11_polygons.json → 3_11.glb
# 3D saved → out_3d_colour/3_11.glb
# [91/264] 3_20_polygons.json → 3_20.glb
# 3D saved → out_3d_colour/3_20.glb
# [92/264] 3_22_polygons.json → 3_22.glb
# 3D saved → out_3d_colour/3_22.glb
# [93/264] 3_4_polygons.json → 3_4.glb
# 3D saved → out_3d_colour/3_4.glb
# [94/264] 40_8_polygons.json → 40_8.glb
# 3D saved → out_3d_colour/40_8.glb
# [95/264] 41_13_polygons.json → 41_13.glb
# 3D saved → out_3d_colour/41_13.glb
# [96/264] 41_14_polygons.json → 41_14.glb
# 3D saved → out_3d_colour/41_14.glb
# [97/264] 41_29_polygons.json → 41_29.glb
# 3D saved → out_3d_colour/41_29.glb
# [98/264] 41_30_polygons.json → 41_30.glb
# 3D saved → out_3d_colour/41_30.glb
# [99/264] 41_5_polygons.json → 41_5.glb
# 3D saved → out_3d_colour/41_5.glb
# [100/264] 41_9_polygons.json → 41_9.glb
# 3D saved → out_3d_colour/41_9.glb
# [101/264] 42_21_polygons.json → 42_21.glb
# 3D saved → out_3d_colour/42_21.glb
# [102/264] 43_1_polygons.json → 43_1.glb
# 3D saved → out_3d_colour/43_1.glb
# [103/264] 44_13_polygons.json → 44_13.glb
# 3D saved → out_3d_colour/44_13.glb
# [104/264] 44_26_polygons.json → 44_26.glb
# 3D saved → out_3d_colour/44_26.glb
# [105/264] 44_4_polygons.json → 44_4.glb
# 3D saved → out_3d_colour/44_4.glb
# [106/264] 44_7_polygons.json → 44_7.glb
# 3D saved → out_3d_colour/44_7.glb
# [107/264] 45_20_polygons.json → 45_20.glb
# 3D saved → out_3d_colour/45_20.glb
# [108/264] 45_30_polygons.json → 45_30.glb
# 3D saved → out_3d_colour/45_30.glb
# [109/264] 47_12_polygons.json → 47_12.glb
# 3D saved → out_3d_colour/47_12.glb
# [110/264] 47_24_polygons.json → 47_24.glb
# 3D saved → out_3d_colour/47_24.glb
# [111/264] 47_30_polygons.json → 47_30.glb
# 3D saved → out_3d_colour/47_30.glb
# [112/264] 48_10_polygons.json → 48_10.glb
# 3D saved → out_3d_colour/48_10.glb
# [113/264] 48_19_polygons.json → 48_19.glb
# 3D saved → out_3d_colour/48_19.glb
# [114/264] 48_29_polygons.json → 48_29.glb
# 3D saved → out_3d_colour/48_29.glb
# [115/264] 48_7_polygons.json → 48_7.glb
# 3D saved → out_3d_colour/48_7.glb
# [116/264] 48_8_polygons.json → 48_8.glb
# 3D saved → out_3d_colour/48_8.glb
# [117/264] 4_19_polygons.json → 4_19.glb
# 3D saved → out_3d_colour/4_19.glb
# [118/264] 4_22_polygons.json → 4_22.glb
# 3D saved → out_3d_colour/4_22.glb
# [119/264] 4_5_polygons.json → 4_5.glb
# 3D saved → out_3d_colour/4_5.glb
# [120/264] 51_18_polygons.json → 51_18.glb
# 3D saved → out_3d_colour/51_18.glb
# [121/264] 51_29_polygons.json → 51_29.glb
# 3D saved → out_3d_colour/51_29.glb
# [122/264] 52_12_polygons.json → 52_12.glb
# 3D saved → out_3d_colour/52_12.glb
# [123/264] 52_17_polygons.json → 52_17.glb
# 3D saved → out_3d_colour/52_17.glb
# [124/264] 52_20_polygons.json → 52_20.glb
# 3D saved → out_3d_colour/52_20.glb
# [125/264] 52_2_polygons.json → 52_2.glb
# 3D saved → out_3d_colour/52_2.glb
# [126/264] 53_14_polygons.json → 53_14.glb
# 3D saved → out_3d_colour/53_14.glb
# [127/264] 53_16_polygons.json → 53_16.glb
# 3D saved → out_3d_colour/53_16.glb
# [128/264] 53_17_polygons.json → 53_17.glb
# 3D saved → out_3d_colour/53_17.glb
# [129/264] 53_6_polygons.json → 53_6.glb
# 3D saved → out_3d_colour/53_6.glb
# [130/264] 54_21_polygons.json → 54_21.glb
# 3D saved → out_3d_colour/54_21.glb
# [131/264] 55_10_polygons.json → 55_10.glb
# 3D saved → out_3d_colour/55_10.glb
# [132/264] 56_13_polygons.json → 56_13.glb
# 3D saved → out_3d_colour/56_13.glb
# [133/264] 57_26_polygons.json → 57_26.glb
# 3D saved → out_3d_colour/57_26.glb
# [134/264] 58_29_polygons.json → 58_29.glb
# 3D saved → out_3d_colour/58_29.glb
# [135/264] 58_30_polygons.json → 58_30.glb
# 3D saved → out_3d_colour/58_30.glb
# [136/264] 58_7_polygons.json → 58_7.glb
# 3D saved → out_3d_colour/58_7.glb
# [137/264] 59_10_polygons.json → 59_10.glb
# 3D saved → out_3d_colour/59_10.glb
# [138/264] 59_14_polygons.json → 59_14.glb
# 3D saved → out_3d_colour/59_14.glb
# [139/264] 59_18_polygons.json → 59_18.glb
# 3D saved → out_3d_colour/59_18.glb
# [140/264] 59_1_polygons.json → 59_1.glb
# 3D saved → out_3d_colour/59_1.glb
# [141/264] 5_16_polygons.json → 5_16.glb
# 3D saved → out_3d_colour/5_16.glb
# [142/264] 5_22_polygons.json → 5_22.glb
# 3D saved → out_3d_colour/5_22.glb
# [143/264] 5_25_polygons.json → 5_25.glb
# 3D saved → out_3d_colour/5_25.glb
# [144/264] 60_19_polygons.json → 60_19.glb
# 3D saved → out_3d_colour/60_19.glb
# [145/264] 60_20_polygons.json → 60_20.glb
# 3D saved → out_3d_colour/60_20.glb
# [146/264] 60_26_polygons.json → 60_26.glb
# 3D saved → out_3d_colour/60_26.glb
# [147/264] 60_6_polygons.json → 60_6.glb
# 3D saved → out_3d_colour/60_6.glb
# [148/264] 60_9_polygons.json → 60_9.glb
# 3D saved → out_3d_colour/60_9.glb
# [149/264] 61_21_polygons.json → 61_21.glb
# 3D saved → out_3d_colour/61_21.glb
# [150/264] 61_24_polygons.json → 61_24.glb
# 3D saved → out_3d_colour/61_24.glb
# [151/264] 62_26_polygons.json → 62_26.glb
# 3D saved → out_3d_colour/62_26.glb
# [152/264] 62_27_polygons.json → 62_27.glb
# 3D saved → out_3d_colour/62_27.glb
# [153/264] 62_29_polygons.json → 62_29.glb
# 3D saved → out_3d_colour/62_29.glb
# [154/264] 63_12_polygons.json → 63_12.glb
# 3D saved → out_3d_colour/63_12.glb
# [155/264] 63_3_polygons.json → 63_3.glb
# 3D saved → out_3d_colour/63_3.glb
# [156/264] 65_20_polygons.json → 65_20.glb
# 3D saved → out_3d_colour/65_20.glb
# [157/264] 65_30_polygons.json → 65_30.glb
# 3D saved → out_3d_colour/65_30.glb
# [158/264] 65_9_polygons.json → 65_9.glb
# 3D saved → out_3d_colour/65_9.glb
# [159/264] 66_16_polygons.json → 66_16.glb
# 3D saved → out_3d_colour/66_16.glb
# [160/264] 66_27_polygons.json → 66_27.glb
# 3D saved → out_3d_colour/66_27.glb
# [161/264] 67_13_polygons.json → 67_13.glb
# 3D saved → out_3d_colour/67_13.glb
# [162/264] 67_27_polygons.json → 67_27.glb
# 3D saved → out_3d_colour/67_27.glb
# [163/264] 67_3_polygons.json → 67_3.glb
# 3D saved → out_3d_colour/67_3.glb
# [164/264] 67_4_polygons.json → 67_4.glb
# 3D saved → out_3d_colour/67_4.glb
# [165/264] 67_8_polygons.json → 67_8.glb
# 3D saved → out_3d_colour/67_8.glb
# [166/264] 68_14_polygons.json → 68_14.glb
# 3D saved → out_3d_colour/68_14.glb
# [167/264] 68_29_polygons.json → 68_29.glb
# 3D saved → out_3d_colour/68_29.glb
# [168/264] 69_11_polygons.json → 69_11.glb
# 3D saved → out_3d_colour/69_11.glb
# [169/264] 6_16_polygons.json → 6_16.glb
# 3D saved → out_3d_colour/6_16.glb
# [170/264] 6_1_polygons.json → 6_1.glb
# 3D saved → out_3d_colour/6_1.glb
# [171/264] 6_21_polygons.json → 6_21.glb
# 3D saved → out_3d_colour/6_21.glb
# [172/264] 6_4_polygons.json → 6_4.glb
# 3D saved → out_3d_colour/6_4.glb
# [173/264] 70_1_polygons.json → 70_1.glb
# 3D saved → out_3d_colour/70_1.glb
# [174/264] 70_21_polygons.json → 70_21.glb
# 3D saved → out_3d_colour/70_21.glb
# [175/264] 70_23_polygons.json → 70_23.glb
# 3D saved → out_3d_colour/70_23.glb
# [176/264] 70_25_polygons.json → 70_25.glb
# 3D saved → out_3d_colour/70_25.glb
# [177/264] 71_12_polygons.json → 71_12.glb
# 3D saved → out_3d_colour/71_12.glb
# [178/264] 71_1_polygons.json → 71_1.glb
# 3D saved → out_3d_colour/71_1.glb
# [179/264] 71_9_polygons.json → 71_9.glb
# 3D saved → out_3d_colour/71_9.glb
# [180/264] 72_10_polygons.json → 72_10.glb
# 3D saved → out_3d_colour/72_10.glb
# [181/264] 72_21_polygons.json → 72_21.glb
# 3D saved → out_3d_colour/72_21.glb
# [182/264] 72_28_polygons.json → 72_28.glb
# 3D saved → out_3d_colour/72_28.glb
# [183/264] 72_3_polygons.json → 72_3.glb
# 3D saved → out_3d_colour/72_3.glb
# [184/264] 73_13_polygons.json → 73_13.glb
# 3D saved → out_3d_colour/73_13.glb
# [185/264] 73_24_polygons.json → 73_24.glb
# 3D saved → out_3d_colour/73_24.glb
# [186/264] 73_30_polygons.json → 73_30.glb
# 3D saved → out_3d_colour/73_30.glb
# [187/264] 74_12_polygons.json → 74_12.glb
# 3D saved → out_3d_colour/74_12.glb
# [188/264] 75_28_polygons.json → 75_28.glb
# 3D saved → out_3d_colour/75_28.glb
# [189/264] 75_7_polygons.json → 75_7.glb
# 3D saved → out_3d_colour/75_7.glb
# [190/264] 75_8_polygons.json → 75_8.glb
# 3D saved → out_3d_colour/75_8.glb
# [191/264] 76_1_polygons.json → 76_1.glb
# 3D saved → out_3d_colour/76_1.glb
# [192/264] 76_29_polygons.json → 76_29.glb
# 3D saved → out_3d_colour/76_29.glb
# [193/264] 76_8_polygons.json → 76_8.glb
# 3D saved → out_3d_colour/76_8.glb
# [194/264] 77_23_polygons.json → 77_23.glb
# 3D saved → out_3d_colour/77_23.glb
# [195/264] 77_27_polygons.json → 77_27.glb
# 3D saved → out_3d_colour/77_27.glb
# [196/264] 78_25_polygons.json → 78_25.glb
# 3D saved → out_3d_colour/78_25.glb
# [197/264] 78_27_polygons.json → 78_27.glb
# 3D saved → out_3d_colour/78_27.glb
# [198/264] 78_4_polygons.json → 78_4.glb
# 3D saved → out_3d_colour/78_4.glb
# [199/264] 79_16_polygons.json → 79_16.glb
# 3D saved → out_3d_colour/79_16.glb
# [200/264] 79_1_polygons.json → 79_1.glb
# 3D saved → out_3d_colour/79_1.glb
# [201/264] 79_25_polygons.json → 79_25.glb
# 3D saved → out_3d_colour/79_25.glb
# [202/264] 79_2_polygons.json → 79_2.glb
# 3D saved → out_3d_colour/79_2.glb
# [203/264] 79_8_polygons.json → 79_8.glb
# 3D saved → out_3d_colour/79_8.glb
# [204/264] 7_28_polygons.json → 7_28.glb
# 3D saved → out_3d_colour/7_28.glb
# [205/264] 7_29_polygons.json → 7_29.glb
# 3D saved → out_3d_colour/7_29.glb
# [206/264] 80_22_polygons.json → 80_22.glb
# 3D saved → out_3d_colour/80_22.glb
# [207/264] 80_3_polygons.json → 80_3.glb
# 3D saved → out_3d_colour/80_3.glb
# [208/264] 81_12_polygons.json → 81_12.glb
# 3D saved → out_3d_colour/81_12.glb
# [209/264] 81_15_polygons.json → 81_15.glb
# 3D saved → out_3d_colour/81_15.glb
# [210/264] 82_10_polygons.json → 82_10.glb
# 3D saved → out_3d_colour/82_10.glb
# [211/264] 82_8_polygons.json → 82_8.glb
# 3D saved → out_3d_colour/82_8.glb
# [212/264] 84_11_polygons.json → 84_11.glb
# 3D saved → out_3d_colour/84_11.glb
# [213/264] 84_18_polygons.json → 84_18.glb
# 3D saved → out_3d_colour/84_18.glb
# [214/264] 84_6_polygons.json → 84_6.glb
# 3D saved → out_3d_colour/84_6.glb
# [215/264] 85_19_polygons.json → 85_19.glb
# 3D saved → out_3d_colour/85_19.glb
# [216/264] 85_21_polygons.json → 85_21.glb
# 3D saved → out_3d_colour/85_21.glb
# [217/264] 86_11_polygons.json → 86_11.glb
# 3D saved → out_3d_colour/86_11.glb
# [218/264] 86_24_polygons.json → 86_24.glb
# 3D saved → out_3d_colour/86_24.glb
# [219/264] 86_25_polygons.json → 86_25.glb
# 3D saved → out_3d_colour/86_25.glb
# [220/264] 86_2_polygons.json → 86_2.glb
# 3D saved → out_3d_colour/86_2.glb
# [221/264] 86_3_polygons.json → 86_3.glb
# 3D saved → out_3d_colour/86_3.glb
# [222/264] 87_15_polygons.json → 87_15.glb
# 3D saved → out_3d_colour/87_15.glb
# [223/264] 87_25_polygons.json → 87_25.glb
# 3D saved → out_3d_colour/87_25.glb
# [224/264] 87_9_polygons.json → 87_9.glb
# 3D saved → out_3d_colour/87_9.glb
# [225/264] 88_15_polygons.json → 88_15.glb
# 3D saved → out_3d_colour/88_15.glb
# [226/264] 88_21_polygons.json → 88_21.glb
# 3D saved → out_3d_colour/88_21.glb
# [227/264] 88_23_polygons.json → 88_23.glb
# 3D saved → out_3d_colour/88_23.glb
# [228/264] 88_9_polygons.json → 88_9.glb
# 3D saved → out_3d_colour/88_9.glb
# [229/264] 89_18_polygons.json → 89_18.glb
# 3D saved → out_3d_colour/89_18.glb
# [230/264] 89_2_polygons.json → 89_2.glb
# 3D saved → out_3d_colour/89_2.glb
# [231/264] 89_4_polygons.json → 89_4.glb
# 3D saved → out_3d_colour/89_4.glb
# [232/264] 89_9_polygons.json → 89_9.glb
# 3D saved → out_3d_colour/89_9.glb
# [233/264] 8_10_polygons.json → 8_10.glb
# 3D saved → out_3d_colour/8_10.glb
# [234/264] 8_18_polygons.json → 8_18.glb
# 3D saved → out_3d_colour/8_18.glb
# [235/264] 8_2_polygons.json → 8_2.glb
# 3D saved → out_3d_colour/8_2.glb
# [236/264] 8_3_polygons.json → 8_3.glb
# 3D saved → out_3d_colour/8_3.glb
# [237/264] 8_8_polygons.json → 8_8.glb
# 3D saved → out_3d_colour/8_8.glb
# [238/264] 90_11_polygons.json → 90_11.glb
# 3D saved → out_3d_colour/90_11.glb
# [239/264] 90_12_polygons.json → 90_12.glb
# 3D saved → out_3d_colour/90_12.glb
# [240/264] 90_23_polygons.json → 90_23.glb
# 3D saved → out_3d_colour/90_23.glb
# [241/264] 90_3_polygons.json → 90_3.glb
# 3D saved → out_3d_colour/90_3.glb
# [242/264] 90_6_polygons.json → 90_6.glb
# 3D saved → out_3d_colour/90_6.glb
# [243/264] 90_8_polygons.json → 90_8.glb
# 3D saved → out_3d_colour/90_8.glb
# [244/264] 91_28_polygons.json → 91_28.glb
# 3D saved → out_3d_colour/91_28.glb
# [245/264] 92_15_polygons.json → 92_15.glb
# 3D saved → out_3d_colour/92_15.glb
# [246/264] 92_29_polygons.json → 92_29.glb
# 3D saved → out_3d_colour/92_29.glb
# [247/264] 93_17_polygons.json → 93_17.glb
# 3D saved → out_3d_colour/93_17.glb
# [248/264] 93_2_polygons.json → 93_2.glb
# 3D saved → out_3d_colour/93_2.glb
# [249/264] 94_17_polygons.json → 94_17.glb
# 3D saved → out_3d_colour/94_17.glb
# [250/264] 94_1_polygons.json → 94_1.glb
# 3D saved → out_3d_colour/94_1.glb
# [251/264] 94_20_polygons.json → 94_20.glb
# 3D saved → out_3d_colour/94_20.glb
# [252/264] 94_4_polygons.json → 94_4.glb
# 3D saved → out_3d_colour/94_4.glb
# [253/264] 95_18_polygons.json → 95_18.glb
# 3D saved → out_3d_colour/95_18.glb
# [254/264] 95_1_polygons.json → 95_1.glb
# 3D saved → out_3d_colour/95_1.glb
# [255/264] 95_24_polygons.json → 95_24.glb
# 3D saved → out_3d_colour/95_24.glb
# [256/264] 95_8_polygons.json → 95_8.glb
# 3D saved → out_3d_colour/95_8.glb
# [257/264] 96_21_polygons.json → 96_21.glb
# 3D saved → out_3d_colour/96_21.glb
# [258/264] 96_28_polygons.json → 96_28.glb
# 3D saved → out_3d_colour/96_28.glb
# [259/264] 98_18_polygons.json → 98_18.glb
# 3D saved → out_3d_colour/98_18.glb
# [260/264] 9_19_polygons.json → 9_19.glb
# 3D saved → out_3d_colour/9_19.glb
# [261/264] 9_1_polygons.json → 9_1.glb
# 3D saved → out_3d_colour/9_1.glb
# [262/264] 9_22_polygons.json → 9_22.glb
# 3D saved → out_3d_colour/9_22.glb
# [263/264] 9_29_polygons.json → 9_29.glb
# 3D saved → out_3d_colour/9_29.glb
# [264/264] 9_7_polygons.json → 9_7.glb
# 3D saved → out_3d_colour/9_7.glb
#
# DONE: exported all available models to out_3d_colour

# %%
from IPython.display import HTML

glb_path = "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_colour/5_25.glb"

HTML(f"""
<model-viewer src="{glb_path}"
    camera-controls
    auto-rotate
    environment-image="neutral"
    style="width:100%; height:600px; background:black;">
</model-viewer>
""")
# Out:
# <model-viewer src="/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_colour/5_25.glb"
#     camera-controls
#     auto-rotate
#     environment-image="neutral"
#     style="width:100%; height:600px; background:black;">
# </model-viewer>
